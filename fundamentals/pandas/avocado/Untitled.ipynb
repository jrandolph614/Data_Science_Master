# %%
import zipfile
with zipfile.ZipFile('archive.zip','r') as zipRef:
    zipRef.extractall('data')

# %%
import pandas as pd
import datetime as dt
df = pd.read_csv('data/avocado.csv')
#df.reset_index(inplace=True)
df.drop(columns=['Unnamed: 0'],inplace=True)
df['Date'] = dt.datetime.strftime(df['Date'],'%Y-%m-%d').strftime('%m/%d/%y')
#df.set_index('Date',inplace=True)
df.index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-7454905ea557> in <module>
#       4 #df.reset_index(inplace=True)
#       5 df.drop(columns=['Unnamed: 0'],inplace=True)
# ----> 6 df['Date'] = dt.datetime.strftime(df['Date'],'%Y-%m-%d').strftime('%m/%d/%y')
#       7 #df.set_index('Date',inplace=True)
#       8 df.index
#
# TypeError: descriptor 'strftime' for 'datetime.date' objects doesn't apply to a 'Series' object

# %%
def change_date(string):
    return dt.datetime.strptime(string,'%Y-%m-%d').strftime('%m/%d/%y')
df['Date']=df['Date'].apply(change_date)

# %%
df
# Out:
#            Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      12/27/15          1.33      64236.62  1036.74   54454.85   48.16
# 1      12/20/15          1.35      54876.98   674.28   44638.81   58.33
# 2      12/13/15          0.93     118220.22   794.70  109149.67  130.50
# 3      12/06/15          1.08      78992.15  1132.00   71976.41   72.58
# 4      11/29/15          1.28      51039.60   941.48   43838.39   75.78
# ...         ...           ...           ...      ...        ...     ...
# 18244  02/04/18          1.63      17074.83  2046.96    1529.20    0.00
# 18245  01/28/18          1.71      13888.04  1191.70    3431.50    0.00
# 18246  01/21/18          1.87      13766.76  1191.92    2452.79  727.94
# 18247  01/14/18          1.93      16205.22  1527.63    2981.04  727.01
# 18248  01/07/18          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...
